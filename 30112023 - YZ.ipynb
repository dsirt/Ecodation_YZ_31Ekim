# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib as mpl

# %%
plt.style.use('seaborn-darkgrid')

# %%
#Line Graphs (Çizgi Grafikleri)

# %%
x = np.array([1,2,3,4,5,6])
y = np.power(x, 3)
plt.plot(x, y)
plt.show()

# %%
x = np.linspace(0, 10, 1000)
y = np.sin(x)
plt.plot(x, y)
plt.show()

# %%
mpl.rcParams.update(mpl.rcParamsDefault)

# %%
x = np.linspace(0, 10, 1000)
y = np.sin(x)
plt.plot(x, y)
plt.show()

# %%
plt.style.use('seaborn-darkgrid')

# %%
plt.figure(figsize = (10,5))
x = np.linspace(0, 10, 1000)
y = np.sin(x)
plt.plot(x, y)
plt.show()

# %%
plt.figure(figsize = (7,3))
x = np.linspace(0, 10, 1000)
y = np.sin(x)
plt.plot(x, y, 'b')
plt.xlabel("X-Axis")
plt.ylabel("Y-Axis")
plt.show()

# %%
plt.figure(figsize = (7,3))
x = np.linspace(0, 10, 1000)
y = np.sin(x)
plt.plot(x, y, 'r')
plt.xlabel("X-Axis")
plt.ylabel("Y-Axis")
plt.show()

# %%
plt.figure(figsize = (7,3))
x = np.linspace(0, 10, 40)
y = np.sin(x)
plt.plot(x, y, 'go')
plt.xlabel("X-Axis")
plt.ylabel("Y-Axis")
plt.show()

# %%
plt.figure(figsize = (7,3))
x = np.linspace(0, 10, 40)
y = np.sin(x)
plt.plot(x, y, 'r^')
plt.xlabel("X-Axis")
plt.ylabel("Y-Axis")
plt.show()

# %%
plt.figure(figsize = (7,3))
x = np.linspace(0, 10, 40)
y = np.sin(x)
plt.plot(x, y, 'rv')
plt.xlabel("X-Axis")
plt.ylabel("Y-Axis")
plt.show()

# %%
#Multiple Data

# %%
x = np.linspace(0, 10, 2000)
plt.figure(figsize = (8, 4))
plt.plot(x, np.sin(x), label = 'Sin(X)')
plt.plot(x, np.cos(x), label = 'Cos(X)')
plt.xlabel('X', fontsize = 18)
plt.ylabel('Y', fontsize = 18)
plt.title("Sin(x) & Cos(x)", fontsize = 14)
plt.legend(loc = 'upper right')
plt.show()

# %%
x = np.linspace(0, 10, 2000)
plt.figure(figsize = (8, 4))
plt.plot(x, np.sin(x), label = 'Sin(X)')
plt.plot(x, np.cos(x), label = 'Cos(X)')
plt.fill_between(x, 0, np.sin(x))
plt.fill_between(x, 0, np.cos(x))
plt.xlabel('X', fontsize = 18)
plt.ylabel('Y', fontsize = 18)
plt.title("Sin(x) & Cos(x)", fontsize = 14)
plt.legend(loc = 'upper right')
plt.show()

# %%
#Multiple Graphs

# %%
plt.figure(figsize = (10, 4))
x = np.linspace(0, 10, 100)
y1 = np.sin(x)
y2 = np.cos(x)
plt.subplot(1,2,1)
plt.plot(x, y1)
plt.subplot(1,2,2)
plt.plot(x, y2)
plt.show()

# %%
plt.figure(figsize = (10, 6))
x = np.linspace(0, 10, 100)
y1 = np.sin(x)
y2 = np.cos(x)

plt.subplot(2,1,1)
plt.plot(x, y1, "b-")

plt.subplot(2,1,2)
plt.plot(x, y2, "r-")

plt.tight_layout()
plt.show()

# %%
#Bar Graphs (Çubuk Grafikler)

# %%
id1 = np.arange(1, 10)
score = np.arange(20, 110, 10)
plt.bar(id1, score)
plt.xlabel('Student ID')
plt.ylabel('Score')
plt.show()

# %%
id1 = np.arange(1, 10)
score = np.arange(20, 110, 10)
plt.figure(figsize = (7,3))
ax = plt.axes()
ax.set_facecolor("#F4FA58")
plt.bar(id1, score, color = '#DF01D7')
plt.xlabel('Student ID')
plt.ylabel('Score')
plt.show()

# %%
#Multiple Data

# %%
x1 = [1,3,5,7]
x2 = [2,4,6,8]
y1 = [7,7,7,7]
y2 = [17,18,29,40]
plt.figure(figsize = (8,6))
ax = plt.axes()
ax.set_facecolor("white")
plt.bar(x1, y1, label = 'First', color = '#42B300')
plt.bar(x2, y2, label = 'Second', color = '#94E413')
plt.xlabel('X')
plt.ylabel('Y')
plt.title('Bar Chart')
plt.legend()
plt.show()

# %%
#Yatay (Horizontal) Bar Grafiği
Age = [28, 33, 43, 45, 57]
Name = ["Doğu", "Batı", "Kuzey", "Güney", "Poyraz"]
plt.barh(Name, Age, color = "yellowgreen")
plt.show()

# %%
num1 = np.array([1,3,5,7,9])
num2 = np.array([2,4,6,8,10])
plt.figure(figsize = (8,4))
plt.bar(num1, num1**2, width = 0.2, color = '#FF6F00')
plt.bar(num2, num2**2, width = 0.2, color = '#FFB300')
plt.show()

# %%
num1 = np.array([1,3,5,7,9])
num2 = np.array([2,4,6,8,10])
plt.figure(figsize = (8,4))
plt.bar(num1, num1**2, width = 0.2, color = '#FF6F00')
plt.bar(num2, num2**2, width = 0.2, color = '#FFB300')
for x, y in zip(num1, num1**2):
    plt.text(x, y + 0.05, '%d' % y, ha = 'center', va = 'bottom')
for x, y in zip(num2, num2**2):
    plt.text(x, y + 0.05, '%d' % y, ha = 'center', va = 'bottom')
plt.show()

# %%
#Stacked Vertical Bar (Üst üste bindirilmiş bar grafikleri)

# %%
x1 = ['Doğu', 'Batı', 'Kuzey', 'Güney']
y1 = [17, 18, 29, 40]
y2 = [20, 21, 22, 23]
plt.figure(figsize = (5,7))
plt.bar(x1, y1, label = 'Open Tickets', width = 0.5, color = '#FF6F00')
plt.bar(x1, y2, label = 'Closed Tickets', width = 0.5, bottom = y1, color = '#FFB300')
plt.xlabel('X')
plt.ylabel('Y')
plt.title('Bar Chart')
plt.legend()
plt.show()

# %%
x1 = ['Doğu', 'Batı', 'Kuzey', 'Güney']
y1 = np.array([17, 18, 29, 40])
y2 = np.array([20, 21, 22, 23])
y3 = np.array([5, 9, 11, 12])
plt.figure(figsize = (5,7))
plt.bar(x1, y1, label = 'Open Tickets', width = 0.5, color = '#FF6F00')
plt.bar(x1, y2, label = 'Closed Tickets', width = 0.5, bottom = y1, color = '#FFB300')
plt.bar(x1, y3, label = 'Cancelled Tickets', width = 0.5, bottom = y1 + y2, color = '#F7DC6F')
plt.xlabel('X')
plt.ylabel('Y')
plt.title('Bar Chart')
plt.legend()
plt.show()

# %%
x1 = ['Doğu', 'Batı', 'Kuzey', 'Güney']
y1 = [17, 18, 29, 40]
y2 = [20, 21, 22, 23]
plt.figure(figsize = (5,7))
plt.bar(x1, y1, label = 'Open Tickets', width = 0.5, color = '#FF6F00')
plt.bar(x1, y2, label = 'Closed Tickets', width = 0.5, bottom = y1, color = '#FFB300')
plt.xlabel('X')
plt.ylabel('Y')
plt.title('Bar Chart')
for x, y in zip(x1, y1):
    plt.text(x, y - 10, '%d' % y, ha = 'center', va = 'bottom')
    
for x, y, z in zip(x1, y2, y1):
    plt.text(x, y + z - 10, '%d' % y, ha = 'center', va = 'bottom')

plt.legend()
plt.show()

# %%
#horizontal
x1 = ['Doğu', 'Batı', 'Kuzey', 'Güney']
y1 = [17, 18, 29, 40]
y2 = [20, 21, 22, 23]
plt.figure(figsize = (8, 5))
plt.barh(x1, y1, label = 'Open Tickets', color = '#FF6F00')
plt.barh(x1, y2, label = 'Closed Tickets', left = y1, color = '#FFB300')
plt.xlabel('X')
plt.ylabel('Y')
plt.title('Bar Chart')
for x, y in zip(x1, y1):
    plt.text(y - 10, x, '%d' % y, ha = 'center', va = 'bottom')
    
for x, y, z in zip(x1, y2, y1):
    plt.text(y + z - 10, x, '%d' % y, ha = 'center', va = 'bottom')

plt.legend()
plt.show()
